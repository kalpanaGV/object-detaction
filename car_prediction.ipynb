# %%
# !pip install ultralytics -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 660.5/660.5 kB 5.5 MB/s eta 0:00:00

# %%
# !yolo detect predict model=yolov8m.pt source="/content/car.mp4.mp4"
# Out:
# Ultralytics YOLOv8.0.227 🚀 Python-3.10.12 torch-2.1.0+cu118 CPU (Intel Xeon 2.20GHz)
# YOLOv8m summary (fused): 218 layers, 25886080 parameters, 0 gradients, 78.9 GFLOPs
#
# video 1/1 (1/323) /content/car.mp4.mp4: 352x640 2 persons, 5 cars, 1 motorcycle, 1 truck, 1195.0ms
# video 1/1 (2/323) /content/car.mp4.mp4: 352x640 2 persons, 5 cars, 1 motorcycle, 1 truck, 1173.5ms
# video 1/1 (3/323) /content/car.mp4.mp4: 352x640 2 persons, 5 cars, 2 motorcycles, 1 truck, 1182.3ms
# video 1/1 (4/323) /content/car.mp4.mp4: 352x640 2 persons, 5 cars, 1 motorcycle, 1 truck, 780.1ms
# video 1/1 (5/323) /content/car.mp4.mp4: 352x640 2 persons, 6 cars, 1 motorcycle, 1 truck, 810.8ms
# video 1/1 (6/323) /content/car.mp4.mp4: 352x640 2 persons, 5 cars, 1 motorcycle, 1 truck, 794.2ms
# video 1/1 (7/323) /content/car.mp4.mp4: 352x640 2 persons, 5 cars, 1 motorcycle, 1 truck, 817.5ms
# video 1/1 (8/323) /content/car.mp4.mp4: 352x640 2 persons, 5 cars, 1 motorcycle, 787.2ms
# ...

# %%
# !ffmpeg -i {"/content/runs/detect/predict/car.mp4.avi"} -vcodec libx264 {"finalcar.mp4"}
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
# ...
